# %% [markdown]
# ### Lista Estruturada:
# 1. **Conjunto de dados e código do projeto**
#    - O conjunto de dados deve ser fornecido como arquivos .csv ou banco de dados SQL Server ou MySQL.
#    - Um arquivo Python ou scripts que representam o código do projeto devem ser incluídos no relatório.
#
# 2. **Estrutura do Relatório**
#    - Descrição do problema abordado pelo projeto.
#    - Meta(s) ou objetivo(s) principais do estudo/projeto.
#    - Descrição do domínio do problema e sua relevância.
#    - Descrição do conjunto de dados, incluindo como foram obtidos e processados.
#    - Insights extraídos dos dados e ferramentas usadas para sua extração.
#    - Pré-processamento de dados e exemplos de código utilizado.
#    - Métricas usadas para avaliar o desempenho.
#    - Três algoritmos de aprendizado de máquina selecionados e uma comparação entre eles.
#    - Resultados comparativos e saídas de diferentes métricas contrastantes.
#    - Visualizações adequadas para apresentar os dados e resultados.
#    - Discussão sobre descobertas derivadas dos modelos criados.
#    - Conclusão sobre o atingimento dos objetivos e lições aprendidas.
#
# ### Checklist:
# - [X] Conjunto de dados fornecido (.csv ou SQL Server/MySQL).
# - [X] Código em Python (.py) incluído no relatório.
# - [ ] Problema do projeto detalhado.
# - [ ] Meta(s) e objetivo(s) principais descritos.
# - [ ] Descrição do domínio e relevância do problema.
# - [ ] Descrição de como os dados foram obtidos.
# - [ ] Insights obtidos dos dados apresentados.
# - [ ] Ferramentas usadas para extração de dados mencionadas.
# - [ ] Pré-processamento de dados descrito com exemplos de código.
# - [ ] Métricas para avaliação de desempenho listadas.
# - [ ] Três algoritmos de aprendizado de máquina comparados.
# - [ ] Comparação de métricas com exemplos de código e saídas.
# - [ ] Visualizações de dados incluídas.
# - [ ] Discussão das descobertas e sua aplicação no mundo real.
# - [ ] Conclusão sobre a utilidade e atingimento dos objetivos.
